# %%
import pandas as pd
import csv
import datetime as dt
import pymongo
from sqlalchemy import create_engine
from config import username, password

# %% [markdown]
# # Extraction

# %%
# Extracted two data sources:
us = pd.read_csv('us-counties.csv')
tax_data = pd.read_csv('2014_irs_tax_returns.csv')
us_counties = pd.read_csv('us_counties_covid19_daily.csv')
states = pd.read_csv('states.csv')

# %%
states.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %% [markdown]
# # Transform

# %% [markdown]
# ### First Dataset

# %%
tax_data.head()
# Out:
#    statefips state  zipcode  agi_stub      n1   mars1   mars2   mars4    prep  \
# 0          1    AL        0         1  850050  481840  115070  240450  479900
# 1          1    AL        0         2  491370  200750  150290  125560  281350
# 2          1    AL        0         3  259540   75820  142970   34070  156720
# 3          1    AL        0         4  164840   26730  125410   10390   99750
# 4          1    AL        0         5  203650   18990  177070    5860  122670
#
#         n2  ...   a10300  n85530  a85530  n85300  a85300  n11901  a11901  \
# 0  1401930  ...   324575       0       0       0       0   62690   47433
# 1  1016010  ...   950446       0       0       0       0   70780  101969
# 2   589190  ...  1319641       0       0       0       0   62170  132373
# 3   423300  ...  1394913       0       0       0       0   45120  124048
# 4   565930  ...  3655700     610     135     270      66   81180  387298
#
#    n11902   a11902  year
# 0  744910  1964826  2014
# 1  413790  1177400  2014
# 2  192050   538160  2014
# 3  115470   375882  2014
# 4  114380   448442  2014
#
# [5 rows x 128 columns]

# %%
taxes = tax_data.drop(columns=['n1','mars1','mars2','mars4','prep','n2','a10300','n85530','a85530']).dropna()

# %%
tax = taxes.drop(columns = ['numdep','total_vita','vita','tce','n06500','a06500','n10300','n85300','a85300','a00200','n00300','a00300',
                           'n00600','a00600','n00650','a00650','n00700','a11070','n10960','n11560','a00700','n00900','a00900','n01000','n59720',
                           'a59720','n11070','a10960','a11560','n11901','a11901','n01400','a01400','n01700','a85775','n09750','a09750','n10600',
                           'a01700','schf','n02300','a02300','n02500','a09400','n85770','n85775','a10600','n59660','a59660','n11902','a11902',
                           'a02500','n26270','a26270','a07230','n07240','a07240','n07220','a07220','n07260','a07260','n09400','a85770','n02900',
                           'a02900','n03220','n05780','a05780','a05780','n07100','a07100','n07300','a07300','n07180','n07230','a03220','n03300',
                           'n19700','a19700','n04800','a04800','n05800','n09600','a09600','a07180','a03300','n03270','a03270','n18450','a18450',
                           'n18500','a18500','n18300','a18300','n19300','a19300','a05800','n03150','a03150','n03210','n03230','a03230','n03240',
                           'a03240','n04470','a04470','a00101','n18425','a18425','a03210','a01000','n02650','n00200','a02650','agi_stub',
                           'statefips','zipcode'])

# %%
tax.head(5000)
# Out:
#      state    a00100  year
# 0       AL  11004990  2014
# 1       AL  17658446  2014
# 2       AL  15963943  2014
# 3       AL  14294375  2014
# 4       AL  27387096  2014
# ...    ...       ...   ...
# 4995    ME     12912  2014
# 4996    ME     28019  2014
# 4997    ME     42402  2014
# 4998    ME     11851  2014
# 4999    ME     24954  2014
#
# [5000 rows x 3 columns]

# %%
tax1 = tax.rename(columns={"state": "Code","a00100":"AGI"})

# %%
tax1.head()
# Out:
#   Code       AGI  year
# 0   AL  11004990  2014
# 1   AL  17658446  2014
# 2   AL  15963943  2014
# 3   AL  14294375  2014
# 4   AL  27387096  2014

# %%
tax_df = tax1.groupby(['Code'])
AGI = tax_df[["AGI"]].sum()
#income_df = tax1.groupby(['Code'])

# %%
AGI.head()
# Out:
#              AGI
# Code
# AK      48753590
# AL     217923266
# AR     130888556
# AZ     333873862
# CA    2628777328

# %% [markdown]
# ### Second Dataset

# %%
us_counties.state.count()
# Out:
# 179696

# %%
us_counties.head(5000)
# Out:
#             date        county         state     fips  cases  deaths
# 0     2020-01-21     Snohomish    Washington  53061.0      1       0
# 1     2020-01-22     Snohomish    Washington  53061.0      1       0
# 2     2020-01-23     Snohomish    Washington  53061.0      1       0
# 3     2020-01-24          Cook      Illinois  17031.0      1       0
# 4     2020-01-24     Snohomish    Washington  53061.0      1       0
# ...          ...           ...           ...      ...    ...     ...
# 4995  2020-03-19         Wayne  Pennsylvania  42127.0      1       0
# 4996  2020-03-19  Westmoreland  Pennsylvania  42129.0      2       0
# 4997  2020-03-19          York  Pennsylvania  42133.0      2       0
# 4998  2020-03-19       Unknown   Puerto Rico      NaN      6       0
# 4999  2020-03-19       Unknown  Rhode Island      NaN     44       0
#
# [5000 rows x 6 columns]

# %%
#counties = us_counties.dropna()

# %%
###Convert state names to abbreviations

# %%
counties1 = us_counties.rename(columns={"state": "State"})

# %%
counties_states = pd.merge(counties1, states, on = 'State')

# %%
covid = counties_states.drop(columns = ['fips','Abbrev','State'])

# %%
covid.head(5000)
# Out:
#             date      county  cases  deaths Code
# 0     2020-01-21   Snohomish      1       0   WA
# 1     2020-01-22   Snohomish      1       0   WA
# 2     2020-01-23   Snohomish      1       0   WA
# 3     2020-01-24   Snohomish      1       0   WA
# 4     2020-01-25   Snohomish      1       0   WA
# ...          ...         ...    ...     ...  ...
# 4995  2020-04-20  Jo Daviess     12       0   IL
# 4996  2020-04-20     Johnson      2       0   IL
# 4997  2020-04-20        Kane    638      31   IL
# 4998  2020-04-20    Kankakee    278      18   IL
# 4999  2020-04-20     Kendall    138       3   IL
#
# [5000 rows x 5 columns]

# %%
covid_df = covid.groupby(['Code'])

# %%
covid_state_count = covid_df["cases","deaths"].sum()

# %%
print(covid_state_count)
# Out:
#          cases   deaths
# Code
# AK       19145      384
# AL      418550    15492
# AR      174291     3556
# AZ      459962    20415
# CA     2861370   110062
# CO      815373    40511
# CT     1397183   111705
# DC      246025    11702
# DE      252358     8480
# FL     1830819    67659
# GA     1365797    57901
# HI       32700      714
# IA      432616    10163
# ID      109416     2988
# IL     3069852   131872
# IN      985788    57031
# KS      250546     6930
# KY      264779    12666
# LA     1517529    94162
# MA     3116917   180601
# MD     1269838    60712
# ME       65481     2609
# MI     2132898   182389
# MN      421122    20716
# MO      420566    19331
# MS      385659    16334
# MT       24835      707
# NC      616951    20838
# ND       60816     1327
# NE      284390     3846
# NH      125669     4931
# NJ     5955875   355268
# NM      191991     7512
# NV      275898    12758
# NY    15782031  1139368
# OH      974321    51868
# OK      199691    11024
# OR      143075     5363
# PA     2465990   137700
# RI      429268    15507
# SC      333773    12747
# SD      131535     1220
# TN      625019    10887
# TX     1667910    44365
# UT      263026     2666
# VA      943867    31084
# VT       47313     2427
# WA      846742    44546
# WI      425471    16619
# WV       59816     2096
# WY       30078      306

# %%
df = covid_summary_df.set_index("Code")
#covid_summary_df = pd.DataFrame({"cases": covid_state_count,"deaths":covid_state_count})
#covid_summary_df.head()

# %%
df.head()
# Out:
#            cases
# Code
# 19145      19145
# 418550    418550
# 174291    174291
# 459962    459962
# 2861370  2861370

# %%
cases_deaths = pd.DataFrame({"cases": covid_state_count,"deaths":covid_state_count})
cases_deaths.head()
# Out:
#            cases      deaths
# Code
# AK      48753590    48753590
# AL     217923266   217923266
# AR     130888556   130888556
# AZ     333873862   333873862
# CA    2628777328  2628777328

# %%
Covid_and_AGI = pd.merge(AGI, cases_deaths, on = 'Code', how = "inner")

# %% [markdown]
# # LOADING

# %% [markdown]
# ### PostGresSQL Database

# %%
db = create_engine(f'postgresql://{username}:{password}@localhost:5432/Covid_db')

# %%
db.table_names()
# Out:
# []

# %%
Covid_and_AGI.to_sql('Covid and AGI', con=db)
